# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StringType
from pyspark.sql.window import Window
import re

# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA med")

# %%
spark = SparkSession.builder.getOrCreate()
raw_df = spark.table("workspace.med.raw_data")

# %%
# strip html tags
def strip_html(text: str) -> str:
    if text is None:
        return None
    
    remove_tags = re.sub(r"<[^>]*>", " ", text)
    return re.sub(r"\s+", " ", remove_tags).strip() # remove whitespace

def normalize_whitespace(text: str) -> str:
    if text is None:
        return None
    
    return re.sub(r"\s+", " ", text).strip()

# %%
strip_html_udf = F.udf(strip_html, StringType())
normalize_whitespace_udf = F.udf(normalize_whitespace, StringType())
