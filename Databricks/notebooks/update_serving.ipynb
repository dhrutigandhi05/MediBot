# %%
# %run ./_bootstrap

# %%
from helpers.update_serving_utils import update_endpoint_to_latest, RETRIEVER_ENDPOINT, RETRIEVER_MODEL, CLASSIFIER_ENDPOINT, CLASSIFIER_MODEL

# %%
update_endpoint_to_latest(RETRIEVER_ENDPOINT, RETRIEVER_MODEL)
update_endpoint_to_latest(CLASSIFIER_ENDPOINT, CLASSIFIER_MODEL)

print("All endpoints updated to latest model versions.")
